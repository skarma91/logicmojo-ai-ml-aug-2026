# %%
print("This is my first python code")
# Out:
# This is my first python code

# %%
print("My name is Sourav Karmakar, and I am learning ML and AI at LogicMojo")
# Out:
# My name is Sourav Karmakar, and I am learning ML and AI at LogicMojo

# %% [markdown]
# # Introduction to Markdown
#
# # Heading-1
# ## Heading-2
# ### Heading-3
# #### Heading-4

# %% [markdown]
# ## Play around with markdown
#
# This is a simple text.
#
# In this notebook we'll explore some cool features of Markdown.
#
# Covert from markdown cell to code cell [shortcut]: esc + y
#
# Convert from code cell to markdown cell [shortcut]: esc + m
#
# To run any cell : shift + enter

# %% [markdown]
# ### Text formatting in markdown
#
# **This stamement is bold**
#
# __This is also a bolded text__
#
# *This is italic text*
#
# _This is also in italics_
#
# ***This is bold + italics***
#
# ___This is also bold + itlaics___
#
# ~~this text is crossed out~~

# %% [markdown]
# ### You can run terminal commands in code cell inside .ipynb notebooks
#
# ```shell
# !<shell command>
# ```

# %%
# !mkdir new_directory  # create a new directory named 'new_directory'

# %%
# !pip install <library_name>  # Replace <library_name> with the actual library you want to install

# %% [markdown]
# ### Quotes in markdown
#
# **Single line Quotes**
#
# > "To err is Human, to forgive is divine"
#
# **Multi line quotes**
#
# > This is the first line of my quote.
# >
# > This is the second line
# >
# > This is the last line
#
# **Nested Quotes**
#
# > Winston Churchill quotes:
# >> "Success is not final, failure is not fatal"

# %% [markdown]
# ### Ordered (Numbered) List
#
# 1. Python is a computer programming language
# 2. Python is an interpreted language
# 2. Python was invented in the year 1991
# 3. Python was invented by Guido Van Rossum as a side solo hobby project
# 3. Currently the latest version of python is 3.14
# 4. Python is widely used in ML and AI

# %% [markdown]
# 1. Bengaluru is a city in India
# 1. Bengaluru is capital city of Karnataka
# 10. Bengaluru is called "Silicon valley of India"
# 1. Bengaluru is famous for its weather and traffic jam
# 1. Bengaluru has very large IT hubs

# %% [markdown]
# ### Unordered List (Bullet points)
#
# - San francisco is a coastal city in USA
# - Boston is another coastal city
# - Arkansas is not a coastal city

# %% [markdown]
# ### Nested list
#
# We are going to cover following topics in ML:
#
# - Supervised Learning
#     1. Linear Regression
#     1. Logistic Regression
#     1. Tree based models
#     1. Bagging and Boosting
# - Unsupervised learning
#     1. Dimensionality Reduction
#     1. Clustering

# %% [markdown]
# ### Hyperlinks
#
# > [text](link to the page)
#
# To learn more about markdown [visit this website](https://www.markdownguide.org/basic-syntax/).

# %% [markdown]
# ### Insert images
#
# >![alt text](path to the image)
#
# ![python logo](Python-Logo.jpg)

# %% [markdown]
# ![lm10](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTK2XN4mkkc6EMhdBQUu93MyU-bXFVmJFF3-SJGN-5cbg&s=10)

# %% [markdown]
# ### Code blocks in markdown
#
# ```python
#
# import numpy
#
# np.random.randint(3,4,5)
#
# my_dictionary = {"x": 1, "y": 2, "z": 3}
# ```

# %% [markdown]
# `this is a single line code block`

# %% [markdown]
# ### Tables in markdown
#
# | Fruits | Price (Rs./kg) | Qty (kg) |
# |:--------|----------------:|:----------:|
# |Apple   | 300            |25        |
# |Oranges | 400            |30        |
# |Pineapple|160  |  15 |

# %% [markdown]
# ### Mathematic symbols and equations (powered by LaTex)
#
# left:
#
# $ E = mc^2 $
#
# centre:
# $$ x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$
