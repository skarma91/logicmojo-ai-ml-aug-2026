# %% [markdown]
# ![](https://matplotlib.org/stable/_images/sphx_glr_logos2_003.png)
#
# ## Matplotlib
#
# - Matplotlib is one of the most popular Python packages used for data visualization.
# - It is a cross-platform library for making 2D plots from data in arrays.
# - It provides an object-oriented API that helps in embedding plots in applications.

# %% [markdown]
# install matplotlib in your virtual environment using
#
# ```
# pip install matplotlib
# ```

# %% [markdown]
# ### Importing the necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt   # from matplotlib import pyplot as plt

# %% [markdown]
# ### Creating data for plot

# %%
x = np.linspace(0, 4*np.pi, 1000)   # np.linsapce(start, stop, num_points)
x.shape
# Out:
# (1000,)

# %%
y = np.sin(x)
y.shape
# Out:
# (1000,)

# %% [markdown]
# ### Line Plot

# %%
plt.figure(figsize = (10,7))    # defining the figure size 
plt.plot(x,y,'r')               # plotting y vs x with red color
plt.grid()                      # adding grid to the plot
plt.xlabel('X')                 # adding label to x-axis
plt.ylabel('sin(X)')            # adding label to y-axis
plt.title('sin(X) vs X')        # adding title to the plot
plt.show()

# %% [markdown]
# ### Simultaneously plotting multiple lineplots in the same figure

# %%
y1 = np.sin(x)
y2 = np.cos(x)

# %%
plt.figure(figsize = (10,6))
plt.plot(x,y1,c = 'b',label = 'sin(x)')
plt.plot(x,y2,c = 'r',label = 'cos(x)')
plt.grid()
plt.legend()
plt.xlabel('X')
plt.ylabel('sin or cos x')
plt.title('My plots')
plt.show()

# %% [markdown]
# ### Few more examples with line plot

# %%
y1 = 2*y1
y2 = 3*y2
plt.figure(figsize = (4,6))
plt.plot(y1,y2)
plt.show()

# %% [markdown]
# ### Subplots
#
# ![](https://scipy-lectures.org/_images/sphx_glr_plot_subplot-grid_thumb.png)

# %%
x = np.linspace(1,10,1000)

y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.log(x)
y4 = np.exp(x)

plt.figure(figsize = (8,8))
plt.suptitle('My plots')

plt.subplot(2,2,1)
plt.plot(x,y1)
plt.title("Sin(X)")

plt.subplot(2,2,2)
plt.plot(x,y2)
plt.title('Cos(x)')

plt.subplot(2,2,3)
plt.plot(x,y3)
plt.title('log(x)');

plt.subplot(2,2,4)
plt.plot(x,y4)
plt.title('exp(x)');

# %%
plt.figure(figsize=(10,6))
plt.plot(x, y1, label = 'sin(x)')
plt.plot(x, y4, label = 'exp(x)')
plt.grid()
plt.legend()
plt.show()

# %%
# Plot 6 subplots
# 1. sin(x)
# 2. cos(x)
# 3,4. log(x)
# 5,6. exp(x)

x = np.linspace(0.001,10,1000)

# %%
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.log(x)
y4 = np.exp(x)

# %%
plt.figure(figsize = (8,8))
plt.suptitle('My plots')

plt.subplot(3,2,1)
plt.plot(x,y1)
plt.title("Sin(X)")
plt.grid()

plt.subplot(3,2,2)
plt.plot(x,y2)
plt.title('Cos(x)')
plt.grid()

plt.subplot(3,2,(3,4))
plt.plot(x,y3)
plt.title('log(x)')
plt.grid()

plt.subplot(3,2,(5,6))
plt.plot(x,y4)
plt.title('exp(x)');
plt.grid()

plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
x = np.random.rand(30)   # 30 random values between 0 to 1

x
# Out:
# array([0.59423608, 0.67472776, 0.16921683, 0.79906286, 0.523946  ,
#        0.22791832, 0.9448661 , 0.44622297, 0.10467451, 0.96301471,
#        0.82543932, 0.483403  , 0.10187468, 0.56544042, 0.94123805,
#        0.54451443, 0.55632583, 0.72837942, 0.37631274, 0.67786356,
#        0.08864922, 0.70946874, 0.5210334 , 0.41751256, 0.71860507,
#        0.18763133, 0.54583577, 0.71322854, 0.77071649, 0.90214376])

# %%
y = np.random.rand(30)

y
# Out:
# array([0.86743323, 0.71254323, 0.62689214, 0.84512048, 0.27346887,
#        0.09835115, 0.27077939, 0.50934044, 0.45660641, 0.73294058,
#        0.37962192, 0.3851514 , 0.57846536, 0.98178638, 0.01786695,
#        0.61084655, 0.06782875, 0.42266891, 0.08725604, 0.34194294,
#        0.16883124, 0.73891248, 0.88823546, 0.41220093, 0.73496719,
#        0.82962666, 0.56782473, 0.08468629, 0.4730746 , 0.42167792])

# %%
plt.scatter(x,y,c='r', edgecolor='k')
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()

# %% [markdown]
# ### Bar Plot

# %%
def add_labels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i]-2.5, y[i],c='k')

# %%
values = [10, 15, 5, 19, 23, 17]

x = ['A', 'B', 'C', 'D', 'E', 'F']

plt.bar(x, height = values, width=0.8, edgecolor = 'k', color= 'c')

add_labels(x, values)

plt.show()

# %%
labels = ['Jan', 'Feb', 'Mar']

values = [100, 150, 90]

 

# Create bar chart

fig, ax = plt.subplots()

bars = ax.bar(labels, values)

 

# Add value labels on top of each bar

ax.bar_label(bars, label_type='center')

plt.show()

# %% [markdown]
# ### Horizontal Bar Plot

# %%
values = [10,15,5,19,23,17]

plt.barh(y = np.arange(1,7), width = values)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ### Histogram Plot

# %%
n = np.random.randn(1000)  # Normally distributed 10000 data points

plt.figure(figsize = (10,5))

plt.hist(n, bins = 20, color = 'c', edgecolor = 'k');   # default bins = 10

# x - axis shows the range and intervals, y axis shows the frequency of each intervals

# %% [markdown]
# ### Pie Chart

# %%
values = [10, 30, 5, 25]
labels = ['X','Y','Z','W']
explode = [0.0, 0.0, 0.1, 0.0]

plt.pie(values, labels=labels, autopct='%.1f%%', startangle=-50, shadow=False, explode=explode)

plt.show()

# %%
plt.bar(x=labels, height=values)
# Out:
# <BarContainer object of 4 artists>

# %%
labels = 'A', 'B', 'C', 'D'
sizes = [132, 235, 56, 98]
explode = (0, 0.1, 0, 0)

plt.figure(figsize = (6,6))

plt.pie(sizes, labels=labels, explode=explode, shadow=True, startangle=90, autopct='%1.1f%%')

plt.show()

# %% [markdown]
# ### 3D Scatter Plot

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.random.rand(30)
y = np.random.rand(30)
z = np.random.rand(30)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(111, projection = '3d')
ax.scatter3D(x,y,z)
plt.show()

# %% [markdown]
# ### 3D surface plot

# %%
(x1,y1) = np.meshgrid(x,y)

# %%
z1 = x1**2 + y1**2 - 45

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(111, projection = '3d')
ax.plot_surface(x1,y1,z1)
plt.show()

# %% [markdown]
# For 3D plotting use more advanced plotting libraries like Plotly

# %% [markdown]
# ![](https://seaborn.pydata.org/_static/logo-wide-lightbg.svg)
#
#
# ## Seaborn
#
# - Seaborn is an amazing data visualization library for statistical graphics plotting in Python.
# - It provides beautiful default styles and colour palettes to make statistical plots more attractive.
# - It is built on the top of the matplotlib library and also closely integrated to the data structures from pandas.
#
#
# Install seaborn using
# ```
# pip install seaborn
# ```

# %% [markdown]
# ### Load Data To Construct Seaborn Plots
#
# There are some built-in datasets in seaborn, which comes very handy while practicing seaborn.

# %%
import seaborn as sns
print(sns.get_dataset_names())
print(len(sns.get_dataset_names()))
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']
# 22

# %%
df = sns.load_dataset('car_crashes')
print(df.head())
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
len(df)
# Out:
# 51

# %% [markdown]
# ### Styling and Themes in Seaborn

# %%
plt.scatter(df.alcohol,df.speeding, edgecolor='k', color='c')
plt.xlabel('Alcohol')
plt.ylabel('Speeding')
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_theme(style = 'dark')
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style("whitegrid")
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style("dark")
plt.show()

# %%
plt.scatter('speeding','alcohol',data=df)
sns.set_style("darkgrid", {'grid.color': '.3'})
sns.despine()
plt.show()

# %% [markdown]
# ### Joint Plot
#
# Joint Plot draws a plot of two variables with bivariate and univariate graphs. It uses the Scatter Plot and Histogram. Joint Plot can also display data using Kernel Density Estimate (KDE) and Hexagons.

# %%
sns.set_style("dark")
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_theme(style = 'darkgrid')
sns.jointplot(x='total_bill', y='tip',data=tips)

# %% [markdown]
# ### Regplot
#
# Regplot is one of the functions in Seaborn that are used to visualize the linear relationship as determined through regression. Also, you‘ll see a slightly shaded portion around the regression line which indicates how much the points are scattered around a certain area. Here are few of the examples

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Pairplot

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.set_style("ticks")
sns.pairplot(df,hue = 'species',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %% [markdown]
# ### Countplot

# %%
# load dataset
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.set_context('paper')
sns.countplot(x = 'class', hue = 'who', data = titanic)
plt.title('Survivors')
plt.show()

# stacked bar graph

# %% [markdown]
# ## Pandas visualization

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv")

# %%
df.shape
# Out:
# (173, 21)

# %%
df.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
df.plot(x="Rank", y="P75th");

# %%
df.plot(x="Rank", y=["P25th","Median", "P75th"])
# Out:
# <Axes: xlabel='Rank'>

# %%
df["Median"].plot(kind="hist",edgecolor='k')
# Out:
# <Axes: ylabel='Frequency'>

# %%
top_medians = df[df["Median"] > 60000].sort_values("Median")

top_medians.plot(x="Major", y=["P25th", "Median", "P75th"], kind="bar")
# Out:
# <Axes: xlabel='Major'>

# %%
df.plot(x="Median", y="Unemployment_rate", kind="scatter")
# Out:
# <Axes: xlabel='Median', ylabel='Unemployment_rate'>
